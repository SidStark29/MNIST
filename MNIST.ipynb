# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from tensorflow.keras.datasets import mnist

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %%
s1 = X_train[0, :, :]
plt.imshow(s1, cmap='Greys')

# %%
print(s1.min(), s1.max())
# Out:
# 0 255

# %%
print(y_train[0])
# Out:
# 5

# %%
from tensorflow.keras.utils import to_categorical

# %%
y_train = to_categorical(y_train, dtype = 'uint8')
y_test = to_categorical(y_test, dtype = 'uint8')

# %%
y_test.shape
# Out:
# (10000, 10)

# %%
X_train = X_train.reshape((60000, -1))
X_test = X_test.reshape((10000, -1))

# %%
X_train.shape
# Out:
# (60000, 784)

# %%
# convert from integers to floats
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %%
# normalize to range 0-1
X_train = X_train / 255.0
X_test = X_test / 255.0

# %% [markdown]
# Model SetUp

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(8, input_dim = 784, activation = 'relu'))
model.add(Dense(16, activation = 'relu'))
model.add(Dense(10,activation = 'softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_21 (Dense)            (None, 8)                 6280
#
#  dense_22 (Dense)            (None, 16)                144
#
#  dense_23 (Dense)            (None, 10)                170
#
# =================================================================
# Total params: 6,594
# Trainable params: 6,594
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Training

# %%
model.compile(loss= 'categorical_crossentropy',optimizer= 'adam', metrics=['accuracy'])

# %%
hist= model.fit(x= X_train, y= y_train, batch_size= 25, validation_data=(X_test, y_test), epochs= 40, verbose=1)
# Out:
# Epoch 1/40
# 2400/2400 [==============================] - 6s 3ms/step - loss: 0.1500 - accuracy: 0.9536 - val_loss: 0.2233 - val_accuracy: 0.9406
# Epoch 2/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1509 - accuracy: 0.9535 - val_loss: 0.2264 - val_accuracy: 0.9377
# Epoch 3/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1509 - accuracy: 0.9542 - val_loss: 0.2172 - val_accuracy: 0.9405
# Epoch 4/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1500 - accuracy: 0.9539 - val_loss: 0.2206 - val_accuracy: 0.9410
# Epoch 5/40
# 2400/2400 [==============================] - 6s 3ms/step - loss: 0.1501 - accuracy: 0.9538 - val_loss: 0.2216 - val_accuracy: 0.9392
# Epoch 6/40
# 2400/2400 [==============================] - 7s 3ms/step - loss: 0.1495 - accuracy: 0.9538 - val_loss: 0.2296 - val_accuracy: 0.9353
# Epoch 7/40
# 2400/2400 [==============================] - 6s 3ms/step - loss: 0.1496 - accuracy: 0.9533 - val_loss: 0.2200 - val_accuracy: 0.9387
# Epoch 8/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1494 - accuracy: 0.9534 - val_loss: 0.2348 - val_accuracy: 0.9353
# Epoch 9/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1494 - accuracy: 0.9539 - val_loss: 0.2201 - val_accuracy: 0.9380
# Epoch 10/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1483 - accuracy: 0.9539 - val_loss: 0.2290 - val_accuracy: 0.9392
# Epoch 11/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1481 - accuracy: 0.9542 - val_loss: 0.2328 - val_accuracy: 0.9383
# Epoch 12/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1481 - accuracy: 0.9540 - val_loss: 0.2199 - val_accuracy: 0.9400
# Epoch 13/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1476 - accuracy: 0.9550 - val_loss: 0.2358 - val_accuracy: 0.9355
# Epoch 14/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1473 - accuracy: 0.9543 - val_loss: 0.2376 - val_accuracy: 0.9361
# Epoch 15/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1472 - accuracy: 0.9550 - val_loss: 0.2294 - val_accuracy: 0.9399
# Epoch 16/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1479 - accuracy: 0.9545 - val_loss: 0.2255 - val_accuracy: 0.9404
# Epoch 17/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1467 - accuracy: 0.9546 - val_loss: 0.2292 - val_accuracy: 0.9367
# Epoch 18/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1458 - accuracy: 0.9555 - val_loss: 0.2281 - val_accuracy: 0.9385
# Epoch 19/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1464 - accuracy: 0.9549 - val_loss: 0.2340 - val_accuracy: 0.9376
# Epoch 20/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1457 - accuracy: 0.9555 - val_loss: 0.2261 - val_accuracy: 0.9405
# Epoch 21/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1455 - accuracy: 0.9553 - val_loss: 0.2301 - val_accuracy: 0.9371
# Epoch 22/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1455 - accuracy: 0.9551 - val_loss: 0.2269 - val_accuracy: 0.9371
# Epoch 23/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1447 - accuracy: 0.9558 - val_loss: 0.2265 - val_accuracy: 0.9396
# Epoch 24/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1454 - accuracy: 0.9552 - val_loss: 0.2294 - val_accuracy: 0.9386
# Epoch 25/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1444 - accuracy: 0.9551 - val_loss: 0.2386 - val_accuracy: 0.9357
# Epoch 26/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1434 - accuracy: 0.9554 - val_loss: 0.2405 - val_accuracy: 0.9382
# Epoch 27/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1439 - accuracy: 0.9551 - val_loss: 0.2310 - val_accuracy: 0.9384
# Epoch 28/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1448 - accuracy: 0.9550 - val_loss: 0.2329 - val_accuracy: 0.9376
# Epoch 29/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1432 - accuracy: 0.9560 - val_loss: 0.2312 - val_accuracy: 0.9394
# Epoch 30/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1440 - accuracy: 0.9553 - val_loss: 0.2340 - val_accuracy: 0.9367
# Epoch 31/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1432 - accuracy: 0.9553 - val_loss: 0.2274 - val_accuracy: 0.9382
# Epoch 32/40
# 2400/2400 [==============================] - 6s 3ms/step - loss: 0.1427 - accuracy: 0.9560 - val_loss: 0.2318 - val_accuracy: 0.9393
# Epoch 33/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1436 - accuracy: 0.9562 - val_loss: 0.2339 - val_accuracy: 0.9383
# Epoch 34/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1428 - accuracy: 0.9560 - val_loss: 0.2254 - val_accuracy: 0.9395
# Epoch 35/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1428 - accuracy: 0.9561 - val_loss: 0.2253 - val_accuracy: 0.9412
# Epoch 36/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1424 - accuracy: 0.9557 - val_loss: 0.2256 - val_accuracy: 0.9395
# Epoch 37/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1424 - accuracy: 0.9562 - val_loss: 0.2311 - val_accuracy: 0.9385
# Epoch 38/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1415 - accuracy: 0.9564 - val_loss: 0.2363 - val_accuracy: 0.9372
# Epoch 39/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1411 - accuracy: 0.9561 - val_loss: 0.2290 - val_accuracy: 0.9377
# Epoch 40/40
# 2400/2400 [==============================] - 6s 2ms/step - loss: 0.1412 - accuracy: 0.9564 - val_loss: 0.2363 - val_accuracy: 0.9377
